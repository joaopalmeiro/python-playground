# %% [markdown]
# # Test JupyterLab notifications
#
# ## References
#
# - https://jupyterlab.readthedocs.io/en/stable/user/commands_list.html#apputils-notify
# - https://jupyterlab.readthedocs.io/en/stable/user/commands.html#commands-in-markdown-files
# - https://jupyterlab.readthedocs.io/en/stable/user/commands.html#apputils-notify
# - https://jupyterlab.readthedocs.io/en/stable/extension/ui_helpers.html#using-commands
# - https://discourse.jupyter.org/t/commandlinker-proper-syntax-for-command-arguments/26610/4
# - https://jupyterlab.readthedocs.io/en/stable/extension/ui_helpers.html#notifications
# - https://github.com/jupyterlab/jupyterlab/blob/v4.3.2/packages/apputils-extension/style/notification.css#L119-L137
# - https://github.com/jupyterlab/jupyterlab/blob/v4.3.2/packages/apputils-extension/src/notificationplugin.tsx#L933

# %% [markdown]
# ---

# %% [markdown]
# <button type="button" data-commandLinker-command="apputils:notify" data-commandlinker-args='{"message": "info", "type": "info", "options": {"autoClose": 3000}}'>Show info notification</button>

# %% [markdown]
# <button type="button" data-commandLinker-command="apputils:notify" data-commandlinker-args='{"message": "success", "type": "success", "options": {"autoClose": 3000}}'>Show success notification</button>

# %% [markdown]
# <button type="button" data-commandLinker-command="apputils:notify" data-commandlinker-args='{"message": "in-progress", "type": "in-progress", "options": {"autoClose": 3000}}'>Show in-progress notification</button>

# %% [markdown]
# <button type="button" data-commandLinker-command="apputils:notify" data-commandlinker-args='{"message": "warning", "type": "warning", "options": {"autoClose": 3000}}'>Show warning notification</button>

# %% [markdown]
# <button type="button" data-commandLinker-command="apputils:notify" data-commandlinker-args='{"message": "error", "type": "error", "options": {"autoClose": 3000}}'>Show error notification</button>

# %% [markdown]
# <button type="button" data-commandLinker-command="apputils:notify" data-commandlinker-args='{"message": "default", "type": "default", "options": {"autoClose": 3000}}'>Show default notification</button>

# %% [markdown]
# ---
